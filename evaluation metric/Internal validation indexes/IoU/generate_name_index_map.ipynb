# %%
from iou_constants import data_dir, result_dir
import numpy as np
import os
from tqdm import tqdm
import pickle

# %%
data_list = sorted(os.listdir(data_dir))
name_index = {}

# %%
for idx, name in enumerate(tqdm(data_list)):
    name_index[name] = idx
# Out:
# 100%|██████████| 22968/22968 [00:00<00:00, 1901707.05it/s]

# %%
index_name = np.array(data_list)

# %%
# def save_obj(obj, name, obj_dir):
#     with open(os.path.join(obj_dir, name) + '.pkl', 'wb') as f:
#         pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# def load_obj(name, obj_dir):
#     with open(os.path.join(obj_dir, name) + '.pkl', 'rb') as f:
#         return pickle.load(f)

# %%
# save_obj(name_index, "name_index", result_dir)
# np.save(os.path.join(result_dir, "index_name"), result_dir)

# %%
name_index
# Out:
# {'00000002': 0,
#  '00000003': 1,
#  '00000004': 2,
#  '00000006': 3,
#  '00000008': 4,
#  '00000009': 5,
#  '00000022': 6,
#  '00000026': 7,
#  '00000027': 8,
#  '00000030': 9,
#  '00000031': 10,
#  '00000032': 11,
#  '00000049': 12,
#  '00000054': 13,
#  '00000057': 14,
#  '00000058': 15,
#  '00000060': 16,
#  '00000061': 17,
#  '00000063': 18,
#  '00000065': 19,
#  '00000066': 20,
#  '00000067': 21,
#  '00000068': 22,
#  '00000070': 23,
#  '00000072': 24,
#  '00000077': 25,
#  '00000078': 26,
#  '00000079': 27,
#  '00000088': 28,
#  '00000090': 29,
#  '00000093': 30,
#  '00000098': 31,
#  '00000103': 32,
#  '00000104': 33,
#  '00000105': 34,
#  '00000106': 35,
#  '00000111': 36,
#  '00000112': 37,
#  '00000115': 38,
#  '00000116': 39,
#  '00000117': 40,
#  '00000119': 41,
#  '00000120': 42,
#  '00000123': 43,
#  '00000125': 44,
#  '00000127': 45,
#  '00000128': 46,
#  '00000129': 47,
#  '00000130': 48,
#  '00000131': 49,
#  '00000132': 50,
#  '00000133': 51,
#  '00000134': 52,
# ...

# %%
index_name
# Out:
# array(['00000002', '00000003', '00000004', ..., '00049988', '00049993',
#        '00049997'], dtype='<U8')
