# %%
import os
import csv
from tqdm import tqdm
import numpy as np

# %%
result_dir = '/scratch/yk1962/ABC/result/chamfer_distance_result'
data_dir = '/scratch/yk1962/ABC/data/pc_correct_num_40960'

# %%
result_list = os.listdir(result_dir)
data_list = os.listdir(data_dir)
start_end = {}
for full_name in result_list:
    split = full_name.split('_')
    try:
        start = int(split[-2])
        end = int(split[-1].split('.')[0])
    except:
        print(full_name)
        break
    start_end[start] = end

# %%
def find_next_in_dict(start_end, start):
    keys = np.array(list(start_end.keys()))
    after_start = keys[keys > start]
    return min(after_start)

current_start = 0
num_res = len(result_list)
error_list = [""]
print_step = 50
for result_count in range(num_res):
    try:
        current_end = start_end[current_start]
    except:
        current_end = find_next_in_dict(start_end, current_start)
        full_name = "chamfer_distance_{}_{}.csv".format(current_start, current_end)
        print("missing the result", full_name)
        if error_list[-1] != full_name: error_list.append(full_name)
        current_start = current_end
        if result_count % print_step == 0:
            print("result", result_count, "finished.")
        continue
    full_name = "chamfer_distance_{}_{}.csv".format(current_start, current_end)
    row_count = 0
    with open(os.path.join(result_dir, full_name), 'r', newline='') as current_result:
        for row_idx, row in enumerate(csv.reader(current_result)):
            try:
                assert(len(row) == current_start + row_idx + 1)
            except:
                print("number of columns in row", row_idx, "of file", full_name, "should be", current_start + row_idx + 1, \
                     "but get", len(row), "instead.")
                if error_list[-1] != full_name: error_list.append(full_name) 
            row_count += 1
    try:
        assert(row_count == current_end - current_start)
    except:
        print("number of rows of file", full_name, "should be", current_end - current_start, \
              "but get", row_count, "instead.")
        if error_list[-1] != full_name: error_list.append(full_name)
    current_start = current_end
    if result_count % print_step == 0:
        print("result", result_count, "finished.")
            
error_list = error_list[1:]
print("number of results:", num_res)
print("numer of errors:", len(error_list))
print("error list:")
print(error_list)
try:
    assert(current_end == len(data_list))
except:
    print("expecting", len(data_list), "objects but get", current_end, "objects")
# Out:
# result 0 finished.
# result 50 finished.
# result 100 finished.
# result 150 finished.
# result 200 finished.
# number of columns in row 1 of file chamfer_distance_17724_17741.csv should be 17726 but get 17725 instead.
# number of columns in row 2 of file chamfer_distance_17724_17741.csv should be 17727 but get 17725 instead.
# number of columns in row 3 of file chamfer_distance_17724_17741.csv should be 17728 but get 17725 instead.
# number of columns in row 4 of file chamfer_distance_17724_17741.csv should be 17729 but get 17726 instead.
# number of columns in row 5 of file chamfer_distance_17724_17741.csv should be 17730 but get 17726 instead.
# number of columns in row 6 of file chamfer_distance_17724_17741.csv should be 17731 but get 17726 instead.
# number of columns in row 7 of file chamfer_distance_17724_17741.csv should be 17732 but get 17726 instead.
# number of columns in row 8 of file chamfer_distance_17724_17741.csv should be 17733 but get 17727 instead.
# number of columns in row 9 of file chamfer_distance_17724_17741.csv should be 17734 but get 17727 instead.
# number of columns in row 10 of file chamfer_distance_17724_17741.csv should be 17735 but get 17727 instead.
# number of columns in row 11 of file chamfer_distance_17724_17741.csv should be 17736 but get 17727 instead.
# number of columns in row 12 of file chamfer_distance_17724_17741.csv should be 17737 but get 17728 instead.
# number of columns in row 13 of file chamfer_distance_17724_17741.csv should be 17738 but get 17728 instead.
# number of columns in row 14 of file chamfer_distance_17724_17741.csv should be 17739 but get 17728 instead.
# number of columns in row 15 of file chamfer_distance_17724_17741.csv should be 17740 but get 17728 instead.
# number of columns in row 16 of file chamfer_distance_17724_17741.csv should be 17741 but get 17729 instead.
# number of columns in row 17 of file chamfer_distance_17724_17741.csv should be 17742 but get 17729 instead.
# number of columns in row 18 of file chamfer_distance_17724_17741.csv should be 17743 but get 17729 instead.
# number of columns in row 19 of file chamfer_distance_17724_17741.csv should be 17744 but get 17729 instead.
# number of columns in row 20 of file chamfer_distance_17724_17741.csv should be 17745 but get 17725 instead.
# number of columns in row 21 of file chamfer_distance_17724_17741.csv should be 17746 but get 17730 instead.
# number of columns in row 22 of file chamfer_distance_17724_17741.csv should be 17747 but get 17730 instead.
# number of columns in row 23 of file chamfer_distance_17724_17741.csv should be 17748 but get 17730 instead.
# number of columns in row 24 of file chamfer_distance_17724_17741.csv should be 17749 but get 17730 instead.
# number of columns in row 25 of file chamfer_distance_17724_17741.csv should be 17750 but get 17726 instead.
# number of columns in row 26 of file chamfer_distance_17724_17741.csv should be 17751 but get 17731 instead.
# number of columns in row 27 of file chamfer_distance_17724_17741.csv should be 17752 but get 17731 instead.
# number of columns in row 28 of file chamfer_distance_17724_17741.csv should be 17753 but get 17731 instead.
# number of columns in row 29 of file chamfer_distance_17724_17741.csv should be 17754 but get 17731 instead.
# number of columns in row 30 of file chamfer_distance_17724_17741.csv should be 17755 but get 17727 instead.
# number of columns in row 31 of file chamfer_distance_17724_17741.csv should be 17756 but get 17732 instead.
# number of columns in row 32 of file chamfer_distance_17724_17741.csv should be 17757 but get 17732 instead.
# number of columns in row 33 of file chamfer_distance_17724_17741.csv should be 17758 but get 17732 instead.
# number of columns in row 34 of file chamfer_distance_17724_17741.csv should be 17759 but get 17732 instead.
# number of columns in row 35 of file chamfer_distance_17724_17741.csv should be 17760 but get 17728 instead.
# number of columns in row 36 of file chamfer_distance_17724_17741.csv should be 17761 but get 17733 instead.
# number of columns in row 37 of file chamfer_distance_17724_17741.csv should be 17762 but get 17733 instead.
# number of columns in row 38 of file chamfer_distance_17724_17741.csv should be 17763 but get 17733 instead.
# number of columns in row 39 of file chamfer_distance_17724_17741.csv should be 17764 but get 17733 instead.
# number of columns in row 40 of file chamfer_distance_17724_17741.csv should be 17765 but get 17729 instead.
# number of columns in row 41 of file chamfer_distance_17724_17741.csv should be 17766 but get 17734 instead.
# number of columns in row 42 of file chamfer_distance_17724_17741.csv should be 17767 but get 17734 instead.
# number of columns in row 43 of file chamfer_distance_17724_17741.csv should be 17768 but get 17734 instead.
# number of columns in row 44 of file chamfer_distance_17724_17741.csv should be 17769 but get 17734 instead.
# number of columns in row 45 of file chamfer_distance_17724_17741.csv should be 17770 but get 17730 instead.
# number of columns in row 46 of file chamfer_distance_17724_17741.csv should be 17771 but get 17735 instead.
# number of columns in row 47 of file chamfer_distance_17724_17741.csv should be 17772 but get 17735 instead.
# number of columns in row 48 of file chamfer_distance_17724_17741.csv should be 17773 but get 17735 instead.
# number of columns in row 49 of file chamfer_distance_17724_17741.csv should be 17774 but get 17735 instead.
# number of columns in row 50 of file chamfer_distance_17724_17741.csv should be 17775 but get 17731 instead.
# number of columns in row 51 of file chamfer_distance_17724_17741.csv should be 17776 but get 17736 instead.
# number of columns in row 52 of file chamfer_distance_17724_17741.csv should be 17777 but get 17736 instead.
# number of columns in row 53 of file chamfer_distance_17724_17741.csv should be 17778 but get 17736 instead.
# number of columns in row 54 of file chamfer_distance_17724_17741.csv should be 17779 but get 17736 instead.
# number of columns in row 55 of file chamfer_distance_17724_17741.csv should be 17780 but get 17732 instead.
# number of columns in row 56 of file chamfer_distance_17724_17741.csv should be 17781 but get 17737 instead.
# number of columns in row 57 of file chamfer_distance_17724_17741.csv should be 17782 but get 17737 instead.
# number of columns in row 58 of file chamfer_distance_17724_17741.csv should be 17783 but get 17737 instead.
# number of columns in row 59 of file chamfer_distance_17724_17741.csv should be 17784 but get 17737 instead.
# number of columns in row 60 of file chamfer_distance_17724_17741.csv should be 17785 but get 17733 instead.
# number of columns in row 61 of file chamfer_distance_17724_17741.csv should be 17786 but get 17738 instead.
# number of columns in row 62 of file chamfer_distance_17724_17741.csv should be 17787 but get 17738 instead.
# number of columns in row 63 of file chamfer_distance_17724_17741.csv should be 17788 but get 17738 instead.
# number of columns in row 64 of file chamfer_distance_17724_17741.csv should be 17789 but get 17738 instead.
# number of columns in row 65 of file chamfer_distance_17724_17741.csv should be 17790 but get 17739 instead.
# number of columns in row 66 of file chamfer_distance_17724_17741.csv should be 17791 but get 17739 instead.
# number of columns in row 67 of file chamfer_distance_17724_17741.csv should be 17792 but get 17739 instead.
# number of columns in row 68 of file chamfer_distance_17724_17741.csv should be 17793 but get 17734 instead.
# number of columns in row 69 of file chamfer_distance_17724_17741.csv should be 17794 but get 17739 instead.
# number of columns in row 70 of file chamfer_distance_17724_17741.csv should be 17795 but get 17740 instead.
# number of columns in row 71 of file chamfer_distance_17724_17741.csv should be 17796 but get 17740 instead.
# number of columns in row 72 of file chamfer_distance_17724_17741.csv should be 17797 but get 17740 instead.
# number of columns in row 73 of file chamfer_distance_17724_17741.csv should be 17798 but get 17740 instead.
# number of columns in row 74 of file chamfer_distance_17724_17741.csv should be 17799 but get 17735 instead.
# number of columns in row 75 of file chamfer_distance_17724_17741.csv should be 17800 but get 17741 instead.
# number of columns in row 76 of file chamfer_distance_17724_17741.csv should be 17801 but get 17741 instead.
# number of columns in row 77 of file chamfer_distance_17724_17741.csv should be 17802 but get 17741 instead.
# number of columns in row 78 of file chamfer_distance_17724_17741.csv should be 17803 but get 17741 instead.
# number of columns in row 79 of file chamfer_distance_17724_17741.csv should be 17804 but get 17736 instead.
# number of columns in row 80 of file chamfer_distance_17724_17741.csv should be 17805 but get 17737 instead.
# number of columns in row 81 of file chamfer_distance_17724_17741.csv should be 17806 but get 17738 instead.
# number of columns in row 82 of file chamfer_distance_17724_17741.csv should be 17807 but get 17739 instead.
# number of columns in row 83 of file chamfer_distance_17724_17741.csv should be 17808 but get 17740 instead.
# number of columns in row 84 of file chamfer_distance_17724_17741.csv should be 17809 but get 17741 instead.
# number of rows of file chamfer_distance_17724_17741.csv should be 17 but get 85 instead.
# missing the result chamfer_distance_17741_17813.csv
# number of columns in row 1 of file chamfer_distance_17813_17830.csv should be 17815 but get 17814 instead.
# number of columns in row 2 of file chamfer_distance_17813_17830.csv should be 17816 but get 17814 instead.
# number of columns in row 3 of file chamfer_distance_17813_17830.csv should be 17817 but get 17815 instead.
# number of columns in row 4 of file chamfer_distance_17813_17830.csv should be 17818 but get 17815 instead.
# number of columns in row 5 of file chamfer_distance_17813_17830.csv should be 17819 but get 17815 instead.
# number of columns in row 6 of file chamfer_distance_17813_17830.csv should be 17820 but get 17814 instead.
# number of columns in row 7 of file chamfer_distance_17813_17830.csv should be 17821 but get 17814 instead.
# number of columns in row 8 of file chamfer_distance_17813_17830.csv should be 17822 but get 17816 instead.
# number of columns in row 9 of file chamfer_distance_17813_17830.csv should be 17823 but get 17816 instead.
# number of columns in row 10 of file chamfer_distance_17813_17830.csv should be 17824 but get 17816 instead.
# number of columns in row 11 of file chamfer_distance_17813_17830.csv should be 17825 but get 17815 instead.
# number of columns in row 12 of file chamfer_distance_17813_17830.csv should be 17826 but get 17815 instead.
# number of columns in row 13 of file chamfer_distance_17813_17830.csv should be 17827 but get 17817 instead.
# number of columns in row 14 of file chamfer_distance_17813_17830.csv should be 17828 but get 17817 instead.
# number of columns in row 15 of file chamfer_distance_17813_17830.csv should be 17829 but get 17817 instead.
# number of columns in row 16 of file chamfer_distance_17813_17830.csv should be 17830 but get 17816 instead.
# number of columns in row 17 of file chamfer_distance_17813_17830.csv should be 17831 but get 17816 instead.
# number of columns in row 18 of file chamfer_distance_17813_17830.csv should be 17832 but get 17818 instead.
# number of columns in row 19 of file chamfer_distance_17813_17830.csv should be 17833 but get 17818 instead.
# number of columns in row 20 of file chamfer_distance_17813_17830.csv should be 17834 but get 17818 instead.
# number of columns in row 21 of file chamfer_distance_17813_17830.csv should be 17835 but get 17817 instead.
# number of columns in row 22 of file chamfer_distance_17813_17830.csv should be 17836 but get 17817 instead.
# number of columns in row 23 of file chamfer_distance_17813_17830.csv should be 17837 but get 17819 instead.
# number of columns in row 24 of file chamfer_distance_17813_17830.csv should be 17838 but get 17819 instead.
# number of columns in row 25 of file chamfer_distance_17813_17830.csv should be 17839 but get 17819 instead.
# number of columns in row 26 of file chamfer_distance_17813_17830.csv should be 17840 but get 17818 instead.
# number of columns in row 27 of file chamfer_distance_17813_17830.csv should be 17841 but get 17818 instead.
# number of columns in row 28 of file chamfer_distance_17813_17830.csv should be 17842 but get 17820 instead.
# number of columns in row 29 of file chamfer_distance_17813_17830.csv should be 17843 but get 17820 instead.
# number of columns in row 30 of file chamfer_distance_17813_17830.csv should be 17844 but get 17820 instead.
# number of columns in row 31 of file chamfer_distance_17813_17830.csv should be 17845 but get 17819 instead.
# number of columns in row 32 of file chamfer_distance_17813_17830.csv should be 17846 but get 17821 instead.
# number of columns in row 33 of file chamfer_distance_17813_17830.csv should be 17847 but get 17819 instead.
# number of columns in row 34 of file chamfer_distance_17813_17830.csv should be 17848 but get 17821 instead.
# number of columns in row 35 of file chamfer_distance_17813_17830.csv should be 17849 but get 17821 instead.
# number of columns in row 36 of file chamfer_distance_17813_17830.csv should be 17850 but get 17820 instead.
# number of columns in row 37 of file chamfer_distance_17813_17830.csv should be 17851 but get 17822 instead.
# number of columns in row 38 of file chamfer_distance_17813_17830.csv should be 17852 but get 17820 instead.
# number of columns in row 39 of file chamfer_distance_17813_17830.csv should be 17853 but get 17822 instead.
# number of columns in row 40 of file chamfer_distance_17813_17830.csv should be 17854 but get 17822 instead.
# number of columns in row 41 of file chamfer_distance_17813_17830.csv should be 17855 but get 17821 instead.
# number of columns in row 42 of file chamfer_distance_17813_17830.csv should be 17856 but get 17823 instead.
# number of columns in row 43 of file chamfer_distance_17813_17830.csv should be 17857 but get 17821 instead.
# number of columns in row 44 of file chamfer_distance_17813_17830.csv should be 17858 but get 17823 instead.
# number of columns in row 45 of file chamfer_distance_17813_17830.csv should be 17859 but get 17823 instead.
# number of columns in row 46 of file chamfer_distance_17813_17830.csv should be 17860 but get 17822 instead.
# number of columns in row 47 of file chamfer_distance_17813_17830.csv should be 17861 but get 17824 instead.
# number of columns in row 48 of file chamfer_distance_17813_17830.csv should be 17862 but get 17822 instead.
# number of columns in row 49 of file chamfer_distance_17813_17830.csv should be 17863 but get 17824 instead.
# number of columns in row 50 of file chamfer_distance_17813_17830.csv should be 17864 but get 17824 instead.
# number of columns in row 51 of file chamfer_distance_17813_17830.csv should be 17865 but get 17823 instead.
# number of columns in row 52 of file chamfer_distance_17813_17830.csv should be 17866 but get 17825 instead.
# number of columns in row 53 of file chamfer_distance_17813_17830.csv should be 17867 but get 17823 instead.
# number of columns in row 54 of file chamfer_distance_17813_17830.csv should be 17868 but get 17825 instead.
# number of columns in row 55 of file chamfer_distance_17813_17830.csv should be 17869 but get 17825 instead.
# number of columns in row 56 of file chamfer_distance_17813_17830.csv should be 17870 but get 17824 instead.
# number of columns in row 57 of file chamfer_distance_17813_17830.csv should be 17871 but get 17826 instead.
# number of columns in row 58 of file chamfer_distance_17813_17830.csv should be 17872 but get 17824 instead.
# number of columns in row 59 of file chamfer_distance_17813_17830.csv should be 17873 but get 17826 instead.
# number of columns in row 60 of file chamfer_distance_17813_17830.csv should be 17874 but get 17826 instead.
# number of columns in row 61 of file chamfer_distance_17813_17830.csv should be 17875 but get 17825 instead.
# number of columns in row 62 of file chamfer_distance_17813_17830.csv should be 17876 but get 17827 instead.
# number of columns in row 63 of file chamfer_distance_17813_17830.csv should be 17877 but get 17825 instead.
# number of columns in row 64 of file chamfer_distance_17813_17830.csv should be 17878 but get 17827 instead.
# number of columns in row 65 of file chamfer_distance_17813_17830.csv should be 17879 but get 17826 instead.
# number of columns in row 66 of file chamfer_distance_17813_17830.csv should be 17880 but get 17827 instead.
# number of columns in row 67 of file chamfer_distance_17813_17830.csv should be 17881 but get 17828 instead.
# number of columns in row 68 of file chamfer_distance_17813_17830.csv should be 17882 but get 17826 instead.
# number of columns in row 69 of file chamfer_distance_17813_17830.csv should be 17883 but get 17828 instead.
# number of columns in row 70 of file chamfer_distance_17813_17830.csv should be 17884 but get 17827 instead.
# number of columns in row 71 of file chamfer_distance_17813_17830.csv should be 17885 but get 17828 instead.
# number of columns in row 72 of file chamfer_distance_17813_17830.csv should be 17886 but get 17829 instead.
# number of columns in row 73 of file chamfer_distance_17813_17830.csv should be 17887 but get 17827 instead.
# number of columns in row 74 of file chamfer_distance_17813_17830.csv should be 17888 but get 17829 instead.
# number of columns in row 75 of file chamfer_distance_17813_17830.csv should be 17889 but get 17828 instead.
# number of columns in row 76 of file chamfer_distance_17813_17830.csv should be 17890 but get 17829 instead.
# number of columns in row 77 of file chamfer_distance_17813_17830.csv should be 17891 but get 17830 instead.
# number of columns in row 78 of file chamfer_distance_17813_17830.csv should be 17892 but get 17828 instead.
# number of columns in row 79 of file chamfer_distance_17813_17830.csv should be 17893 but get 17830 instead.
# number of columns in row 80 of file chamfer_distance_17813_17830.csv should be 17894 but get 17829 instead.
# number of columns in row 81 of file chamfer_distance_17813_17830.csv should be 17895 but get 17830 instead.
# number of columns in row 82 of file chamfer_distance_17813_17830.csv should be 17896 but get 17829 instead.
# number of columns in row 83 of file chamfer_distance_17813_17830.csv should be 17897 but get 17830 instead.
# number of columns in row 84 of file chamfer_distance_17813_17830.csv should be 17898 but get 17830 instead.
# number of rows of file chamfer_distance_17813_17830.csv should be 17 but get 85 instead.
# missing the result chamfer_distance_17830_17902.csv
# number of columns in row 2 of file chamfer_distance_19181_19197.csv should be 19184 but get 19182 instead.
# number of columns in row 3 of file chamfer_distance_19181_19197.csv should be 19185 but get 19182 instead.
# number of columns in row 4 of file chamfer_distance_19181_19197.csv should be 19186 but get 19182 instead.
# number of columns in row 5 of file chamfer_distance_19181_19197.csv should be 19187 but get 19184 instead.
# number of columns in row 6 of file chamfer_distance_19181_19197.csv should be 19188 but get 19183 instead.
# number of columns in row 7 of file chamfer_distance_19181_19197.csv should be 19189 but get 19183 instead.
# number of columns in row 8 of file chamfer_distance_19181_19197.csv should be 19190 but get 19183 instead.
# number of columns in row 9 of file chamfer_distance_19181_19197.csv should be 19191 but get 19185 instead.
# number of columns in row 10 of file chamfer_distance_19181_19197.csv should be 19192 but get 19184 instead.
# number of columns in row 11 of file chamfer_distance_19181_19197.csv should be 19193 but get 19184 instead.
# number of columns in row 12 of file chamfer_distance_19181_19197.csv should be 19194 but get 19184 instead.
# number of columns in row 13 of file chamfer_distance_19181_19197.csv should be 19195 but get 19186 instead.
# number of columns in row 14 of file chamfer_distance_19181_19197.csv should be 19196 but get 19185 instead.
# number of columns in row 15 of file chamfer_distance_19181_19197.csv should be 19197 but get 19185 instead.
# number of columns in row 16 of file chamfer_distance_19181_19197.csv should be 19198 but get 19185 instead.
# number of columns in row 17 of file chamfer_distance_19181_19197.csv should be 19199 but get 19187 instead.
# number of columns in row 18 of file chamfer_distance_19181_19197.csv should be 19200 but get 19186 instead.
# number of columns in row 19 of file chamfer_distance_19181_19197.csv should be 19201 but get 19186 instead.
# number of columns in row 20 of file chamfer_distance_19181_19197.csv should be 19202 but get 19186 instead.
# number of columns in row 21 of file chamfer_distance_19181_19197.csv should be 19203 but get 19188 instead.
# number of columns in row 22 of file chamfer_distance_19181_19197.csv should be 19204 but get 19187 instead.
# number of columns in row 23 of file chamfer_distance_19181_19197.csv should be 19205 but get 19187 instead.
# number of columns in row 24 of file chamfer_distance_19181_19197.csv should be 19206 but get 19187 instead.
# number of columns in row 25 of file chamfer_distance_19181_19197.csv should be 19207 but get 19189 instead.
# number of columns in row 26 of file chamfer_distance_19181_19197.csv should be 19208 but get 19188 instead.
# number of columns in row 27 of file chamfer_distance_19181_19197.csv should be 19209 but get 19188 instead.
# number of columns in row 28 of file chamfer_distance_19181_19197.csv should be 19210 but get 19188 instead.
# number of columns in row 29 of file chamfer_distance_19181_19197.csv should be 19211 but get 19190 instead.
# number of columns in row 30 of file chamfer_distance_19181_19197.csv should be 19212 but get 19189 instead.
# number of columns in row 31 of file chamfer_distance_19181_19197.csv should be 19213 but get 19189 instead.
# number of columns in row 32 of file chamfer_distance_19181_19197.csv should be 19214 but get 19189 instead.
# number of columns in row 33 of file chamfer_distance_19181_19197.csv should be 19215 but get 19191 instead.
# number of columns in row 34 of file chamfer_distance_19181_19197.csv should be 19216 but get 19190 instead.
# number of columns in row 35 of file chamfer_distance_19181_19197.csv should be 19217 but get 19190 instead.
# number of columns in row 36 of file chamfer_distance_19181_19197.csv should be 19218 but get 19190 instead.
# number of columns in row 37 of file chamfer_distance_19181_19197.csv should be 19219 but get 19192 instead.
# number of columns in row 38 of file chamfer_distance_19181_19197.csv should be 19220 but get 19191 instead.
# number of columns in row 39 of file chamfer_distance_19181_19197.csv should be 19221 but get 19191 instead.
# number of columns in row 40 of file chamfer_distance_19181_19197.csv should be 19222 but get 19191 instead.
# number of columns in row 41 of file chamfer_distance_19181_19197.csv should be 19223 but get 19193 instead.
# number of columns in row 42 of file chamfer_distance_19181_19197.csv should be 19224 but get 19192 instead.
# number of columns in row 43 of file chamfer_distance_19181_19197.csv should be 19225 but get 19192 instead.
# number of columns in row 44 of file chamfer_distance_19181_19197.csv should be 19226 but get 19192 instead.
# number of columns in row 45 of file chamfer_distance_19181_19197.csv should be 19227 but get 19194 instead.
# number of columns in row 46 of file chamfer_distance_19181_19197.csv should be 19228 but get 19193 instead.
# number of columns in row 47 of file chamfer_distance_19181_19197.csv should be 19229 but get 19193 instead.
# number of columns in row 48 of file chamfer_distance_19181_19197.csv should be 19230 but get 19193 instead.
# number of columns in row 49 of file chamfer_distance_19181_19197.csv should be 19231 but get 19194 instead.
# number of columns in row 50 of file chamfer_distance_19181_19197.csv should be 19232 but get 19195 instead.
# number of columns in row 51 of file chamfer_distance_19181_19197.csv should be 19233 but get 19194 instead.
# number of columns in row 52 of file chamfer_distance_19181_19197.csv should be 19234 but get 19194 instead.
# number of columns in row 53 of file chamfer_distance_19181_19197.csv should be 19235 but get 19182 instead.
# number of columns in row 54 of file chamfer_distance_19181_19197.csv should be 19236 but get 19195 instead.
# number of columns in row 55 of file chamfer_distance_19181_19197.csv should be 19237 but get 19196 instead.
# number of columns in row 56 of file chamfer_distance_19181_19197.csv should be 19238 but get 19195 instead.
# number of columns in row 57 of file chamfer_distance_19181_19197.csv should be 19239 but get 19195 instead.
# number of columns in row 58 of file chamfer_distance_19181_19197.csv should be 19240 but get 19183 instead.
# number of columns in row 59 of file chamfer_distance_19181_19197.csv should be 19241 but get 19196 instead.
# number of columns in row 60 of file chamfer_distance_19181_19197.csv should be 19242 but get 19197 instead.
# number of columns in row 61 of file chamfer_distance_19181_19197.csv should be 19243 but get 19196 instead.
# number of columns in row 62 of file chamfer_distance_19181_19197.csv should be 19244 but get 19196 instead.
# number of columns in row 63 of file chamfer_distance_19181_19197.csv should be 19245 but get 19184 instead.
# number of columns in row 64 of file chamfer_distance_19181_19197.csv should be 19246 but get 19197 instead.
# number of columns in row 65 of file chamfer_distance_19181_19197.csv should be 19247 but get 19197 instead.
# number of columns in row 66 of file chamfer_distance_19181_19197.csv should be 19248 but get 19197 instead.
# number of columns in row 67 of file chamfer_distance_19181_19197.csv should be 19249 but get 19185 instead.
# number of columns in row 68 of file chamfer_distance_19181_19197.csv should be 19250 but get 19186 instead.
# number of columns in row 69 of file chamfer_distance_19181_19197.csv should be 19251 but get 19187 instead.
# number of columns in row 70 of file chamfer_distance_19181_19197.csv should be 19252 but get 19188 instead.
# number of columns in row 71 of file chamfer_distance_19181_19197.csv should be 19253 but get 19189 instead.
# number of columns in row 72 of file chamfer_distance_19181_19197.csv should be 19254 but get 19190 instead.
# number of columns in row 73 of file chamfer_distance_19181_19197.csv should be 19255 but get 19191 instead.
# number of columns in row 74 of file chamfer_distance_19181_19197.csv should be 19256 but get 19192 instead.
# number of columns in row 75 of file chamfer_distance_19181_19197.csv should be 19257 but get 19193 instead.
# number of columns in row 76 of file chamfer_distance_19181_19197.csv should be 19258 but get 19194 instead.
# number of columns in row 77 of file chamfer_distance_19181_19197.csv should be 19259 but get 19195 instead.
# number of columns in row 78 of file chamfer_distance_19181_19197.csv should be 19260 but get 19196 instead.
# number of columns in row 79 of file chamfer_distance_19181_19197.csv should be 19261 but get 19197 instead.
# number of rows of file chamfer_distance_19181_19197.csv should be 16 but get 80 instead.
# missing the result chamfer_distance_19197_19263.csv
# missing the result chamfer_distance_19589_19670.csv
# result 250 finished.
# missing the result chamfer_distance_20535_20612.csv
# missing the result chamfer_distance_22517_22587.csv
# number of results: 283
# numer of errors: 9
# error list:
# ['chamfer_distance_17724_17741.csv', 'chamfer_distance_17741_17813.csv', 'chamfer_distance_17813_17830.csv', 'chamfer_distance_17830_17902.csv', 'chamfer_distance_19181_19197.csv', 'chamfer_distance_19197_19263.csv', 'chamfer_distance_19589_19670.csv', 'chamfer_distance_20535_20612.csv', 'chamfer_distance_22517_22587.csv']
# expecting 22968 objects but get 22587 objects

# %%
def recalculate(jstart, 
                jend, 
                run_time="11:59:59", 
                gpu_type="rtx8000", 
                sbatch_dir="job_request", 
                split=False, 
                split_num=4,
                project_dir="/scratch/yk1962/ABC",
                data_dir="data/pc_correct_num_40960",
                result_dir="result",
                output_dir="output",
                netid="yk1962",
                activate_path="/scratch/yk1962/miniconda3/bin/activate",
                path_to_code="code",
                main_project_dir="/scratch/yk1962/ABC",
               ):
    content = \
    "#!/bin/bash -e\n" \
    "#\n" \
    "#SBATCH --nodes=1\n" \
    "#SBATCH --ntasks-per-node=1\n" \
    "#SBATCH --cpus-per-task=2\n" \
    "#SBATCH --time={}\n" \
    "#SBATCH --mem=10GB\n" \
    "#SBATCH --job-name=chamfer_distance_{}-{} \n" \
    "#SBATCH --mail-user={}@nyu.edu \n" \
    "#SBATCH --output={}/{}/slurm_%j_{}_{}.out\n" \
    "#SBATCH --gres=gpu:{}:1\n" \
    "\n" \
    "module purge\n" \
    "\n" \
    "# Enter required modules\n" \
    "\n" \
    "# Execute Commands\n" \
    "cd {}/{}\n" \
    "source {} pytorch3d\n" \
    "python chamfer_distance.py {} {} {} -start={} -end={} -cuda_name=cuda:0\n"
        
    if not split:
        content = content.format(run_time,
                                 jstart, jend,
                                 netid,
                                 project_dir, output_dir, jstart, jend,
                                 gpu_type,
                                 project_dir, path_to_code,
                                 activate_path,
                                 project_dir, data_dir, result_dir, jstart, jend)
        job_path = os.path.join(project_dir, sbatch_dir, "job_{}-{}.sh".format(jstart, jend))
        with open(job_path, "w") as f:
            f.write(content)
    else:
        split_range = np.linspace(jstart, jend, split_num+1, dtype=int)
        for i in range(split_num):
            sub_jstart = split_range[i]
            sub_jend = split_range[i+1]
            content = content.format(run_time,
                                 sub_jstart, sub_jend,
                                 netid,
                                 project_dir, output_dir, sub_jstart, sub_jend,
                                 gpu_type,
                                 project_dir, path_to_code,
                                 activate_path,
                                 project_dir, data_dir, result_dir, sub_jstart, sub_jend)
            job_path = os.path.join(main_project_dir, sbatch_dir, "job_{}_{}-{}.sh".format(netid, sub_jstart, sub_jend))
            with open(job_path, "w") as f:
                f.write(content)
#     os.system("sbatch {}".format(job_path))

# %%
if len(error_list) != 0:
    for idx, error_csv in enumerate(error_list):
        os.system("mv {} ~/trash".format(os.path.join(result_dir, error_csv)))
        split = error_csv.split('_')
        start = int(split[-2])
        end = int(split[-1].split('.')[0])
        if idx < len(error_list) // 2:
            recalculate(start, 
                        end, 
                        run_time="11:59:59", 
                        gpu_type="rtx8000", 
                        sbatch_dir="job_request", 
                        split=True, 
                        split_num=5,
                        project_dir="/scratch/yk1962/ABC",
                        data_dir="data/pc_correct_num_40960",
                        result_dir="result",
                        output_dir="output",
                        netid="yk1962",
                        activate_path="/scratch/yk1962/miniconda3/bin/activate",
                        path_to_code="code",
                        main_project_dir="/scratch/yk1962/ABC",
                       )
        else:
            recalculate(start, 
                        end, 
                        run_time="11:59:58", 
                        gpu_type="rtx8000", 
                        sbatch_dir="job_request", 
                        split=True, 
                        split_num=5,
                        project_dir="/scratch/sx783/ABC2",
                        data_dir="data/pc_correct_num_40960",
                        result_dir="result",
                        output_dir="output",
                        netid="sx783",
                        activate_path="/scratch/sx783/miniconda3/bin/activate",
                        path_to_code="code",
                        main_project_dir="/scratch/yk1962/ABC",
                       )
        print("generated job from", start, "to {}.".format(end))
    print("job generated. go to shell to submit the jobs.")

# %%
index_name = {}

n = len(name_list)
name_idx_list = [None] * n
for idx, name in enumerate(name_list):
    index_name[idx] = int(name)
    name_idx_list[idx] = (name, idx)

name_idx_list = sorted(name_idx_list)

name_idx_to_sorted_idx = [] * n
for

# %%
idx = np.where(unsorted_id_to_sorted_id == 0)

# %%
unsorted_id_to_sorted_id[idx]

# %%
name_list[2149]

# %%
name_list[np.where(unsorted_id_to_sorted_id == 0)[0][0]]

# %%
data = [0.] * (n * (n-1) // 2) 
ii = [0] * (n * (n-1) // 2) 
jj = [0] * (n * (n-1) // 2)

# %%
result_names_enum = enumerate(sorted(os.listdir(result_dir)))

count = 0
with open(os.path.join(result_dir, result_names_enum.__next__()[1]), 'r', newline='') as first_csv:
    distance_enum = enumerate(csv.reader(first_csv))
    distance_enum.__next__()
    count = 0
    for row_idx, (_, row) in enumerate(distance_enum):
        row_name = int(row[0])
        try: 
            assert(row_name == index_name[row_idx])
        except:
            print("row:", row_idx, "name:", row_name, "supposed name:", index_name[row_idx])
            break
        
        for col_idx, distance in enumerate(row[1:]):
            distance = float(distance)
            try:
                assert(distance > 0 and distance < 1)
            except:
                raise Exception("distance at row {} column {} is: {}".format(row_idx, col_idx, distance))
            data[count] = distance
            col_name = index_name[col_idx]
            if row_name < col_name:
                ii[count] = row_name
                jj[count] == col_name
            elif row_name == col_name:
                print("row name should not be equal to column name!", row_name)
            else:
                ii[count] = col_name
                jj[count] == row_name
            count += 1

# %%
index_name

# %%
## check integrity

result_list = os.listdir(result_dir)

start_end = {}
for csv_name in result_list:
    split = csv_name.split('_')
    start = int(split[-2])
    end = int(split[-1].split('.')[0])
    start_end[start] = end

# %%
def get_distance(idx1, idx2):

# %%
pc_names = os.listdir(data_dir)
pc_int_name = map(int, pc_names)
name_unsorted_index = {}

for idx, name in enumerate(pc_int_name):
    name_unsorted_index[name] = idx

pc_names_sorted = sorted(pc_names)
indptr = []
data = []
indices = []
for idx1, pc_name in enumerate(tqdm(pc_names_sorted[1:]), start=1):
    indptr.append(0)
    indptr.append(idx1)
    for idx2 in range(idx1):
        data.append()
